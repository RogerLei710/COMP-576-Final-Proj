# %% [markdown]
# # ELEC/COMP 576: Introduction to Deep Learning
# ## Final project
#
# ## author:
# ## netid:

# %% [markdown]
# ## Part 1 Simple evaluation on black box

# %% [markdown]
# ### 1 (a)

# %%
from mnist_attack import plot_misclassifications

# Epsilon value used: 0.2 (when making perturbations)
plot_misclassifications(10, 0)
# Out:
# Accuracy of Substitute model on regular images: [0.13146190345287323, 0.9818999767303467]
# Accuracy of target model on regular images: [0.04570648819208145, 0.9860000014305115]
# Accuracy of Substitute model on adversarial images: [43.223514556884766, 0.019999999552965164]
# Accuracy of target model on adversarial images: [1.0697137117385864, 0.6880000233650208]
# The original image is classified as seven
# The adversarial image is classified as three
# The original image is classified as two
# The adversarial image is classified as five
# The original image is classified as one
# The adversarial image is classified as seven
# The original image is classified as zero
# The adversarial image is classified as nine
# The original image is classified as four
# The adversarial image is classified as five
# The original image is classified as one
# The adversarial image is classified as seven
# The original image is classified as four
# The adversarial image is classified as five
# ...
